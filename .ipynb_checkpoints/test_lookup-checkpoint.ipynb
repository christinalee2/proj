# %%
"""
Test script to evaluate institution lookup service performance
Tests first 300 institutions and calculates accuracy metrics
"""
import pandas as pd
import time
from datetime import datetime
from dotenv import load_dotenv
from services.institution_lookup_service import InstitutionLookupService
from database.queries import QueryService
import json

# Load environment variables
load_dotenv()

class LookupTester:
    def __init__(self, limit=300):
        self.limit = limit
        self.query_service = QueryService()
        
        # Load all institutions to get valid countries
        print("Loading institution table to extract valid countries...")
        all_institutions = self.query_service.get_table_data('institution', limit=None)
        
        # Extract unique country values
        valid_countries = set()
        if 'country_sub' in all_institutions.columns:
            valid_countries.update(all_institutions['country_sub'].dropna().unique())
        if 'country_parent' in all_institutions.columns:
            valid_countries.update(all_institutions['country_parent'].dropna().unique())
        
        print(f"Found {len(valid_countries)} unique countries in institution table")
        
        self.lookup_service = InstitutionLookupService(valid_countries=list(valid_countries))
        self.results = []
        
    def load_institutions(self):
        """Load institutions from database"""
        print(f"Loading first {self.limit} institutions from database...")
        df = self.query_service.get_table_data('institution', limit=self.limit)
        
        # Select relevant columns
        columns = [
            'institution_cpi',
            'institution_type_layer1',
            'institution_type_layer2', 
            'institution_type_layer3',
            'country_sub',
            'country_parent'
        ]
        
        df = df[columns]
        print(f"Loaded {len(df)} institutions")
        return df
    
    def test_institution(self, row):
        """Test lookup for a single institution"""
        institution_name = row['institution_cpi']
        
        print(f"\nTesting: {institution_name}")
        
        try:
            # Perform lookup
            start_time = time.time()
            result = self.lookup_service.lookup_institution(institution_name)
            elapsed_time = time.time() - start_time
            
            # Compare results
            comparison = {
                'institution_name': institution_name,
                'lookup_time_seconds': round(elapsed_time, 2),
                'confidence_score': result.confidence_score,
                
                # Actual values from database
                'actual_type1': row['institution_type_layer1'],
                'actual_type2': row['institution_type_layer2'],
                'actual_type3': row['institution_type_layer3'],
                'actual_country_parent': row['country_parent'],
                'actual_country_sub': row['country_sub'],
                
                # Predicted values from lookup
                'predicted_type1': result.institution_type_layer1,
                'predicted_type2': result.institution_type_layer2,
                'predicted_type3': result.institution_type_layer3,
                'predicted_country_parent': result.parent_country,
                'predicted_country_sub': result.subsidiary_country,
                
                # Match status
                'type1_match': None,
                'type2_match': None,
                'type3_match': None,
                'country_parent_match': None,
                'country_sub_match': None,
                
                'reasoning': result.reasoning,
                'num_sources': len(result.sources)
            }
            
            # Calculate matches (handling None/null values)
            comparison['type1_match'] = self._compare_values(
                row['institution_type_layer1'], 
                result.institution_type_layer1
            )
            comparison['type2_match'] = self._compare_values(
                row['institution_type_layer2'], 
                result.institution_type_layer2
            )
            comparison['type3_match'] = self._compare_values(
                row['institution_type_layer3'], 
                result.institution_type_layer3
            )
            comparison['country_parent_match'] = self._compare_values(
                row['country_parent'], 
                result.parent_country
            )
            comparison['country_sub_match'] = self._compare_values(
                row['country_sub'], 
                result.subsidiary_country
            )
            
            print(f"  Confidence: {result.confidence_score:.2f}")
            print(f"  Type1 Match: {comparison['type1_match']}")
            print(f"  Type2 Match: {comparison['type2_match']}")
            print(f"  Type3 Match: {comparison['type3_match']}")
            print(f"  Country Parent Match: {comparison['country_parent_match']}")
            print(f"  Country Sub Match: {comparison['country_sub_match']}")
            
            return comparison
            
        except Exception as e:
            print(f"  ERROR: {str(e)}")
            return {
                'institution_name': institution_name,
                'error': str(e),
                'lookup_time_seconds': 0,
                'confidence_score': 0.0
            }
    
    def _compare_values(self, actual, predicted):
        """
        Compare actual vs predicted values
        Returns: 'match', 'mismatch', 'no_prediction', 'no_actual', or 'both_null'
        """
        # Normalize values
        actual_clean = self._clean_value(actual)
        predicted_clean = self._clean_value(predicted)
        
        # Both are null/empty
        if not actual_clean and not predicted_clean:
            return 'both_null'
        
        # No actual value in database
        if not actual_clean:
            return 'no_actual'
        
        # No predicted value from lookup
        if not predicted_clean:
            return 'no_prediction'
        
        # Compare values (case-insensitive)
        if actual_clean.lower() == predicted_clean.lower():
            return 'match'
        else:
            return 'mismatch'
    
    def _clean_value(self, value):
        """Clean and normalize a value"""
        if pd.isna(value) or value is None or value == '':
            return None
        return str(value).strip()
    
    def run_test(self, sample_size=None):
        """Run the full test"""
        print("=" * 80)
        print("INSTITUTION LOOKUP SERVICE - PERFORMANCE TEST")
        print("=" * 80)
        print(f"Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print()
        
        # Load institutions
        institutions_df = self.load_institutions()
        
        # Optionally sample
        if sample_size and sample_size < len(institutions_df):
            print(f"\nSampling {sample_size} institutions for testing...")
            institutions_df = institutions_df.sample(n=sample_size, random_state=42)
        
        total = len(institutions_df)
        print(f"\nTesting {total} institutions...")
        print("=" * 80)
        
        # Test each institution
        for idx, row in institutions_df.iterrows():
            print(f"\nProgress: {len(self.results) + 1}/{total}")
            result = self.test_institution(row)
            self.results.append(result)
            
            # Be nice to APIs - small delay between requests
            time.sleep(0.5)
        
        print("\n" + "=" * 80)
        print("TEST COMPLETE")
        print("=" * 80)
        
        # Calculate and display statistics
        self.calculate_statistics()
        
        # Save results
        self.save_results()
    
    def calculate_statistics(self):
        """Calculate and display performance statistics"""
        results_df = pd.DataFrame(self.results)
        
        print("\n" + "=" * 80)
        print("PERFORMANCE STATISTICS")
        print("=" * 80)
        
        # Overall statistics
        print(f"\nTotal Institutions Tested: {len(results_df)}")
        print(f"Average Confidence Score: {results_df['confidence_score'].mean():.2%}")
        print(f"Median Confidence Score: {results_df['confidence_score'].median():.2%}")
        print(f"Average Lookup Time: {results_df['lookup_time_seconds'].mean():.2f}s")
        
        # Confidence distribution
        print("\nConfidence Score Distribution:")
        print(f"  High (>= 0.7): {(results_df['confidence_score'] >= 0.7).sum()} ({(results_df['confidence_score'] >= 0.7).sum() / len(results_df) * 100:.1f}%)")
        print(f"  Medium (0.4-0.7): {((results_df['confidence_score'] >= 0.4) & (results_df['confidence_score'] < 0.7)).sum()} ({((results_df['confidence_score'] >= 0.4) & (results_df['confidence_score'] < 0.7)).sum() / len(results_df) * 100:.1f}%)")
        print(f"  Low (< 0.4): {(results_df['confidence_score'] < 0.4).sum()} ({(results_df['confidence_score'] < 0.4).sum() / len(results_df) * 100:.1f}%)")
        
        # Field-by-field accuracy
        print("\n" + "-" * 80)
        print("FIELD-BY-FIELD ACCURACY")
        print("-" * 80)
        
        fields = [
            ('institution_type_layer1', 'type1_match'),
            ('institution_type_layer2', 'type2_match'),
            ('institution_type_layer3', 'type3_match'),
            ('country_parent', 'country_parent_match'),
            ('country_sub', 'country_sub_match')
        ]
        
        for field_name, match_column in fields:
            print(f"\n{field_name.upper()}:")
            
            # Count match types
            match_counts = results_df[match_column].value_counts()
            total_valid = len(results_df)
            
            matches = match_counts.get('match', 0)
            mismatches = match_counts.get('mismatch', 0)
            no_prediction = match_counts.get('no_prediction', 0)
            no_actual = match_counts.get('no_actual', 0)
            both_null = match_counts.get('both_null', 0)
            
            print(f"  Correct Matches: {matches} ({matches/total_valid*100:.1f}%)")
            print(f"  Mismatches: {mismatches} ({mismatches/total_valid*100:.1f}%)")
            print(f"  No Prediction: {no_prediction} ({no_prediction/total_valid*100:.1f}%)")
            print(f"  No Actual Value: {no_actual} ({no_actual/total_valid*100:.1f}%)")
            print(f"  Both Null: {both_null} ({both_null/total_valid*100:.1f}%)")
            
            # Calculate accuracy (matches / cases where both had values)
            cases_with_both = matches + mismatches
            if cases_with_both > 0:
                accuracy = matches / cases_with_both * 100
                print(f"  --> Accuracy (when both have values): {accuracy:.1f}%")
            
            # Calculate coverage (predictions / cases with actual values)
            cases_with_actual = matches + mismatches + no_prediction
            if cases_with_actual > 0:
                coverage = (matches + mismatches) / cases_with_actual * 100
                print(f"  --> Coverage (predicted when actual exists): {coverage:.1f}%")
        
        # High confidence subset analysis
        high_conf_df = results_df[results_df['confidence_score'] >= 0.7]
        if len(high_conf_df) > 0:
            print("\n" + "-" * 80)
            print(f"HIGH CONFIDENCE SUBSET (>= 0.7 confidence, n={len(high_conf_df)})")
            print("-" * 80)
            
            for field_name, match_column in fields:
                match_counts = high_conf_df[match_column].value_counts()
                matches = match_counts.get('match', 0)
                mismatches = match_counts.get('mismatch', 0)
                cases_with_both = matches + mismatches
                
                if cases_with_both > 0:
                    accuracy = matches / cases_with_both * 100
                    print(f"  {field_name}: {accuracy:.1f}% accuracy")
        
        print("\n" + "=" * 80)
    
    def save_results(self):
        """Save results to CSV files"""
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        
        # Save detailed results
        results_df = pd.DataFrame(self.results)
        filename = f'lookup_test_results_{timestamp}.csv'
        results_df.to_csv(filename, index=False)
        print(f"\nDetailed results saved to: {filename}")
        
        # Save summary statistics
        summary = {
            'test_date': datetime.now().isoformat(),
            'total_tested': len(results_df),
            'avg_confidence': float(results_df['confidence_score'].mean()),
            'median_confidence': float(results_df['confidence_score'].median()),
            'avg_lookup_time': float(results_df['lookup_time_seconds'].mean()),
        }
        
        # Add field accuracies
        fields = [
            ('type1', 'type1_match'),
            ('type2', 'type2_match'),
            ('type3', 'type3_match'),
            ('country_parent', 'country_parent_match'),
            ('country_sub', 'country_sub_match')
        ]
        
        for field_name, match_column in fields:
            match_counts = results_df[match_column].value_counts()
            matches = match_counts.get('match', 0)
            mismatches = match_counts.get('mismatch', 0)
            cases_with_both = matches + mismatches
            
            if cases_with_both > 0:
                summary[f'{field_name}_accuracy'] = float(matches / cases_with_both)
            else:
                summary[f'{field_name}_accuracy'] = None
        
        summary_filename = f'lookup_test_summary_{timestamp}.json'
        with open(summary_filename, 'w') as f:
            json.dump(summary, f, indent=2)
        print(f"Summary statistics saved to: {summary_filename}")


def main():
    """Main function"""
    print("Starting Institution Lookup Performance Test")
    print()
    
    # Create tester
    tester = LookupTester(limit=200)
    
    # Run test (you can pass sample_size to test fewer institutions first)
    # tester.run_test(sample_size=10)  # Test with 10 first
    tester.run_test()  # Test all 300
    
    print("\nTest complete!")


if __name__ == "__main__":
    main()
# Out:
# Starting Institution Lookup Performance Test
#
# Loading institution table to extract valid countries...
# Found 265 unique countries in institution table
# Loaded 265 valid countries from institution table
# ================================================================================
# INSTITUTION LOOKUP SERVICE - PERFORMANCE TEST
# ================================================================================
# Started: 2025-10-14 15:41:26
#
# Loading first 200 institutions from database...
# Loaded 200 institutions
#
# Testing 200 institutions...
# ================================================================================
#
# Progress: 1/200
#
# Testing: 100% RE IPP GmbH & Co KG
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 2/200
#
# Testing: 123Venture SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 3/200
#
# Testing: 127 Energy LLC
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 4/200
#
# Testing: 174 Power Global Corp
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 5/200
#
# Testing: 1st Source Bank
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 6/200
#
# Testing: 1st Source Corp
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 7/200
#
# Testing: 2-B Energy BV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 8/200
#
# Testing: 360 Energy SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 9/200
#
# Testing: 3D Energies
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 10/200
#
# Testing: 3G Energy Corp
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 11/200
#
# Testing: 3i Infrastructure PLC
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 12/200
#
# Testing: 3S Kale Enerji
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 13/200
#
# Testing: 3U Holding AG
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 14/200
#
# Testing: 401 Energy Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 15/200
#
# Testing: 510nano Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 16/200
#
# Testing: Aardwarmte Vogelaer
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 17/200
#
# Testing: Aarvas Wind Oy
#   Confidence: 0.70
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: no_prediction
#   Country Sub Match: no_prediction
#
# Progress: 18/200
#
# Testing: AASA Energia SA
#   Confidence: 0.80
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 19/200
#
# Testing: AB Unternehmensberatung & Beteiligungsgesellschaft mbH
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 20/200
#
# Testing: Aba Hongyuan Huanju Eco Energy Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 21/200
#
# Testing: Aba Ruoergai Huanju Eco Energy Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 22/200
#
# Testing: Abaga Lvneng New Energy Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 23/200
#
# Testing: Abalance Corp
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 24/200
#
# Testing: Abanca Corp Bancaria SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 25/200
#
# Testing: Abantia Group
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 26/200
#
# Testing: Abbey National Treasury Services PLC
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 27/200
#
# Testing: ABC Westland Beheer CV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 28/200
#
# Testing: Abengoa and Cobra
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: mismatch
#
# Progress: 29/200
#
# Testing: Abengoa Bioenergia Brasil SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 30/200
#
# Testing: Abengoa Bioenergia SL
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 31/200
#
# Testing: Abengoa Brasil SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 32/200
#
# Testing: Abengoa SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 33/200
#
# Testing: Abengoa Solar SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 34/200
#
# Testing: Abhimaani Publication Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 35/200
#
# Testing: ABK Enerji Elektrik Uretim AS
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 36/200
#
# Testing: Able Corp
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 37/200
#
# Testing: ABM Greentech Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 38/200
#
# Testing: ABN AMRO Bank NV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 39/200
#
# Testing: ABO Invest AG
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 40/200
#
# Testing: ABO Wind AG
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 41/200
#
# Testing: ABO Wind Sarl
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 42/200
#
# Testing: Aboitiz Renewables Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 43/200
#
# Testing: ABP Investments
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 44/200
#
# Testing: Abraaj Group Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 45/200
#
# Testing: Absa Bank Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 46/200
#
# Testing: Absa Capital Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 47/200
#
# Testing: Absa Group Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 48/200
#
# Testing: 77 Bank Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 49/200
#
# Testing: 7C Solarparken AG
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 50/200
#
# Testing: 7x7 Energie GmbH
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 51/200
#
# Testing: 8minutenergy Renewables LLC
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 52/200
#
# Testing: 8point3 Energy Partners LP
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 53/200
#
# Testing: 9REN Group
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: mismatch
#
# Progress: 54/200
#
# Testing: A V Anjaneya Prasad
#   Confidence: 0.80
#   Type1 Match: mismatch
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 55/200
#
# Testing: A Silva Matos - SGPS SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 56/200
#
# Testing: A2A SpA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 57/200
#
# Testing: Aachi Masala Food'S Pvt Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 58/200
#
# Testing: Aagaard Vindmollelag I/S
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 59/200
#
# Testing: Aalborg Energie Technik A/S
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 60/200
#
# Testing: Aalto Power SAS
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 61/200
#
# Testing: Aamjiwnaang First Nation
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 62/200
#
# Testing: Aardvark EM Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 63/200
#
# Testing: Aardwarmte Vierpolders
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 64/200
#
# Testing: Abu Dhabi Fund For Development
#   Confidence: 1.00
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 65/200
#
# Testing: Abu Dhabi Government
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 66/200
#
# Testing: Abu Dhabi Water & Electricity Authority
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 67/200
#
# Testing: Abundant Ventures Tarn Taran PV Plant
#   Confidence: 0.70
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 68/200
#
# Testing: AC Energy Holdings Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 69/200
#
# Testing: AC Energy Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 70/200
#
# Testing: AC Moore Arts & Crafts Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 71/200
#
# Testing: Acajutla Energia Solar 1 Ltda de CV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 72/200
#
# Testing: Acarsoy Enerji
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 73/200
#
# Testing: Acarsoy Enerji Elektrik
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 74/200
#
# Testing: Access Power MEA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 75/200
#
# Testing: Acciona Energia Chile SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 76/200
#
# Testing: ACCIONA Energia SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 77/200
#
# Testing: ACCIONA Energia Servicios Mexico S de RL de CV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 78/200
#
# Testing: Acciona Energias Renovables SL
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 79/200
#
# Testing: Acciona Energy Oceania Pty Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 80/200
#
# Testing: Acciona SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 81/200
#
# Testing: Acciona Windpower North America LLC
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 82/200
#
# Testing: Acciona Windpower SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 83/200
#
# Testing: Accordia Golf Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 84/200
#
# Testing: Achiha KK
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 85/200
#
# Testing: Acme Cleantech Solutions Pvt Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 86/200
#
# Testing: Acme Group
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 87/200
#
# Testing: Acme Solar Energy Pvt Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 88/200
#
# Testing: ACOFI Gestion SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 89/200
#
# Testing: Acolus Windpark Handewitt V GmbH & Co KG
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 90/200
#
# Testing: AcrEnergy Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 91/200
#
# Testing: Actensys GmbH
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 92/200
#
# Testing: Actis LLP
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 93/200
#
# Testing: Activ Solar GmbH
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 94/200
#
# Testing: ACWA Power Barka SAOG
# DEBUG: LLM said 'Public' but suffix says 'Private' - using suffix
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 95/200
#
# Testing: ACWA Power International
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 96/200
#
# Testing: Adali Holding
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 97/200
#
# Testing: Adani Enterprises Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 98/200
#
# Testing: Adani Green Energy Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: mismatch
#
# Progress: 99/200
#
# Testing: Adani Power Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: mismatch
#
# Progress: 100/200
#
# Testing: Adaptation Fund
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 101/200
#
# Testing: Adaptation for Smallholder Agriculture Programme
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 102/200
#
# Testing: Addison Energy Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: mismatch
#
# Progress: 103/200
#
# Testing: Adeco Agropecuaria SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 104/200
#
# Testing: Adelaide Airport Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 105/200
#
# Testing: Adenium Energy Capital
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 106/200
#
# Testing: Adiant Capital Partners
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: mismatch
#
# Progress: 107/200
#
# Testing: Aditya Birla Finance Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 108/200
#
# Testing: Aditya Birla Group
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 109/200
#
# Testing: Aditya Birla Renewables Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 110/200
#
# Testing: Aditya Mediasales
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 111/200
#
# Testing: Administracion Nacional de Usinas y Trasmisiones Electricas
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 112/200
#
# Testing: Admirals Bank
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 113/200
#
# Testing: Ado Enerji Uretim Sanayi ve Ticaret AS
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 114/200
#
# Testing: Advanced Plasma Power Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 115/200
#
# Testing: Advanced SolTech Renewable Energy Hangzhou Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 116/200
#
# Testing: Advantec Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 117/200
#
# Testing: Aegon Levensverzekering NV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 118/200
#
# Testing: Aela Energia
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 119/200
#
# Testing: Aeolian Stallingborough Ltd
#   Confidence: 0.80
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: no_prediction
#   Country Sub Match: no_prediction
#
# Progress: 120/200
#
# Testing: Aeoliki Akti
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 121/200
#
# Testing: Aeolus Wind Parks Pvt Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 122/200
#
# Testing: Aeon Delight Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 123/200
#
# Testing: AEP Energy Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 124/200
#
# Testing: Aeroenergia SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 125/200
#
# Testing: Aeroplex Aerolease Group
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 126/200
#
# Testing: Aerowatt
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 127/200
#
# Testing: Aerzteversorgung Westfalen-Lippe
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 128/200
#
# Testing: AES Argentina Generacion SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 129/200
#
# Testing: AES Chivor SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 130/200
#
# Testing: AES Corp
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 131/200
#
# Testing: AES Distributed Energy
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 132/200
#
# Testing: AES El Salvador SA de CV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 133/200
#
# Testing: AES Gener SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 134/200
#
# Testing: AES Jordan Solar BV
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 135/200
#
# Testing: AES Solar Energy Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 136/200
#
# Testing: AES Tiete Energia SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 137/200
#
# Testing: Afcon Holdings Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 138/200
#
# Testing: AffaldVarme Arhus
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 139/200
#
# Testing: AFFIN Bank Bhd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 140/200
#
# Testing: AFFIN Islamic Bank Bhd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 141/200
#
# Testing: Affinity Renewables Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 142/200
#
# Testing: Affordable Solar Group LLC
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 143/200
#
# Testing: Africa Finance Corp
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 144/200
#
# Testing: African Export-Import Bank
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 145/200
#
# Testing: African Infrastructure Investment Managers Pty Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 146/200
#
# Testing: AG
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 147/200
#
# Testing: AG Insurance
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 148/200
#
# Testing: Agaoglu Group
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 149/200
#
# Testing: AGC Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 150/200
#
# Testing: Agder Energi AS
# DEBUG: LLM said 'Public' but suffix says 'Private' - using suffix
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 151/200
#
# Testing: Agen SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 152/200
#
# Testing: Agence Francaise de Developpement
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 153/200
#
# Testing: Agencia Central SA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 154/200
#
# Testing: Agency for Non-conventional Energy and Rural Technology
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 155/200
#
# Testing: AGL Energy Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 156/200
#
# Testing: AGR
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 157/200
#
# Testing: Agrawal Group Goa
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 158/200
#
# Testing: Agricola EL Casar SL
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 159/200
#
# Testing: Agricultural Bank of China Ltd
#   Confidence: 0.90
#   Type1 Match: mismatch
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 160/200
#
# Testing: Agricultural Development Bank of China
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 161/200
#
# Testing: AGRIS Solar Co-operative
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 162/200
#
# Testing: Agrivert Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 163/200
#
# Testing: Agro EcoEnergy Tanzania Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 164/200
#
# Testing: Agroctanos SA
#   Confidence: 0.70
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 165/200
#
# Testing: Agroindustrial Piedra Negra
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 166/200
#
# Testing: Agrokor Energija
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 167/200
#
# Testing: Agropecuaria Salto do Leao Ltda
#   Confidence: 0.80
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 168/200
#
# Testing: AGSM Verona SpA
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 169/200
#
# Testing: Ahana Renewables LLC
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 170/200
#
# Testing: Ahaska Aryaa Solar
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 171/200
#
# Testing: Ahill Apparel Exports Pvt Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 172/200
#
# Testing: Ahmedabad Municipal Corp
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: mismatch
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 173/200
#
# Testing: Ahsen Enerji Uretim Ticaret ve San AS
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 174/200
#
# Testing: AIA Engineering Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 175/200
#
# Testing: AIB Group UK PLC
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: match
#
# Progress: 176/200
#
# Testing: Aichi Bank Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 177/200
#
# Testing: Aichi Electric Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 178/200
#
# Testing: Aide Solar Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 179/200
#
# Testing: Aiki Eco Power LLP
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 180/200
#
# Testing: Aikyam Holdings Pvt Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 181/200
#
# Testing: Ailenergie
#   Confidence: 0.80
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 182/200
#
# Testing: AIO Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 183/200
#
# Testing: Air Water Inc
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 184/200
#
# Testing: Airies & Sorbie Holdco Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: no_prediction
#   Country Sub Match: no_prediction
#
# Progress: 185/200
#
# Testing: Airkfraft-Windkraftanlagen Errichtungs-u.Betriebs AG
#   Confidence: 0.80
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 186/200
#
# Testing: Airport Facilities Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 187/200
#
# Testing: Airports Authority of India
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: match
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 188/200
#
# Testing: Airtec System Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 189/200
#
# Testing: Airvolution Energy Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 190/200
#
# Testing: Aizu Electric Power Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 191/200
#
# Testing: AJ Power Pvt Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: mismatch
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 192/200
#
# Testing: Ajith Kumar B Kuchnur
#   Confidence: 0.00
#   Type1 Match: no_prediction
#   Type2 Match: no_prediction
#   Type3 Match: both_null
#   Country Parent Match: no_prediction
#   Country Sub Match: no_prediction
#
# Progress: 193/200
#
# Testing: Aju Co Ltd
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 194/200
#
# Testing: Ak Eco Solar LLP
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: mismatch
#   Country Sub Match: mismatch
#
# Progress: 195/200
#
# Testing: AKA Ausfuhrkredit GmbH
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 196/200
#
# Testing: Akbank AG
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 197/200
#
# Testing: Akbank T.A.S.
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 198/200
#
# Testing: Akca Enerji Group
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 199/200
#
# Testing: Akca Enerji Uretim ve Dagotim Otoproduktor Grubu AS
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# Progress: 200/200
#
# Testing: Akca Holding AS
#   Confidence: 0.90
#   Type1 Match: match
#   Type2 Match: match
#   Type3 Match: no_actual
#   Country Parent Match: match
#   Country Sub Match: match
#
# ================================================================================
# TEST COMPLETE
# ================================================================================
#
# ================================================================================
# PERFORMANCE STATISTICS
# ================================================================================
#
# Total Institutions Tested: 200
# Average Confidence Score: 89.00%
# Median Confidence Score: 90.00%
# Average Lookup Time: 4.08s
#
# Confidence Score Distribution:
#   High (>= 0.7): 199 (99.5%)
#   Medium (0.4-0.7): 0 (0.0%)
#   Low (< 0.4): 1 (0.5%)
#
# --------------------------------------------------------------------------------
# FIELD-BY-FIELD ACCURACY
# --------------------------------------------------------------------------------
#
# INSTITUTION_TYPE_LAYER1:
#   Correct Matches: 188 (94.0%)
#   Mismatches: 11 (5.5%)
#   No Prediction: 1 (0.5%)
#   No Actual Value: 0 (0.0%)
#   Both Null: 0 (0.0%)
#   --> Accuracy (when both have values): 94.5%
#   --> Coverage (predicted when actual exists): 99.5%
#
# INSTITUTION_TYPE_LAYER2:
#   Correct Matches: 170 (85.0%)
#   Mismatches: 29 (14.5%)
#   No Prediction: 1 (0.5%)
#   No Actual Value: 0 (0.0%)
#   Both Null: 0 (0.0%)
#   --> Accuracy (when both have values): 85.4%
#   --> Coverage (predicted when actual exists): 99.5%
#
# INSTITUTION_TYPE_LAYER3:
#   Correct Matches: 22 (11.0%)
#   Mismatches: 37 (18.5%)
#   No Prediction: 0 (0.0%)
#   No Actual Value: 140 (70.0%)
#   Both Null: 1 (0.5%)
#   --> Accuracy (when both have values): 37.3%
#   --> Coverage (predicted when actual exists): 100.0%
#
# COUNTRY_PARENT:
#   Correct Matches: 163 (81.5%)
#   Mismatches: 33 (16.5%)
#   No Prediction: 4 (2.0%)
#   No Actual Value: 0 (0.0%)
#   Both Null: 0 (0.0%)
#   --> Accuracy (when both have values): 83.2%
#   --> Coverage (predicted when actual exists): 98.0%
#
# COUNTRY_SUB:
#   Correct Matches: 174 (87.0%)
#   Mismatches: 22 (11.0%)
#   No Prediction: 4 (2.0%)
#   No Actual Value: 0 (0.0%)
#   Both Null: 0 (0.0%)
#   --> Accuracy (when both have values): 88.8%
#   --> Coverage (predicted when actual exists): 98.0%
#
# --------------------------------------------------------------------------------
# HIGH CONFIDENCE SUBSET (>= 0.7 confidence, n=199)
# --------------------------------------------------------------------------------
#   institution_type_layer1: 94.5% accuracy
#   institution_type_layer2: 85.4% accuracy
#   institution_type_layer3: 37.3% accuracy
#   country_parent: 83.2% accuracy
#   country_sub: 88.8% accuracy
#
# ================================================================================
#
# Detailed results saved to: lookup_test_results_20251014_155645.csv
# Summary statistics saved to: lookup_test_summary_20251014_155645.json
#
# Test complete!
